# %% [markdown]
# # library inclusion

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix 
from sklearn import preprocessing
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.regularizers import L1L2

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
ds1 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Stock_Pred/DataSet/SBIN.csv')
ds2 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Stock_Pred/DataSet/SUNPHARMA.csv')
ds3 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Stock_Pred/DataSet/TATASTEEL.csv')
ds4 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Stock_Pred/DataSet/TCS.csv')
ds1.head()
# Out:
#          Date  Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  03-01-2000     0.1     EQ  ...     NaN                 NaN          NaN
# 1  04-01-2000     0.1     EQ  ...     NaN                 NaN          NaN
# 2  05-01-2000     0.1     EQ  ...     NaN                 NaN          NaN
# 3  06-01-2000     0.1     EQ  ...     NaN                 NaN          NaN
# 4  07-01-2000     0.1     EQ  ...     NaN                 NaN          NaN
#
# [5 rows x 15 columns]

# %% [markdown]
# # SBIN

# %%
ds1.isnull().sum()  #shows the column with nos of null value.
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     514
# %Deliverble            514
# dtype: int64

# %%
# from sklearn.impute import SimpleImputer
# imputer = SimpleImputer(missing_values=np.nan, strategy='mean')  # Fills the null data with the mean of that column.
# imputer = imputer.fit(ds1[['Trades']])
# ds1['Trades'] = imputer.transform(ds1[['Trades']])
# imputer = imputer.fit(ds1[['Deliverable Volume']])
# ds1['Deliverable Volume'] = imputer.transform(ds1[['Deliverable Volume']])
# imputer = imputer.fit(ds1[['%Deliverble']])
# ds1['%Deliverble'] = imputer.transform(ds1[['%Deliverble']])
# ds1.drop(["Series"],axis=1,inplace=True)

# %%
ds1.dropna(axis=1,inplace=True)
ds1.isnull().sum()
# Out:
# Date          0
# Symbol        0
# Series        0
# Prev Close    0
# Open          0
# High          0
# Low           0
# Last          0
# Close         0
# VWAP          0
# Volume        0
# Turnover      0
# dtype: int64

# %%
ds1.drop(['Series','VWAP'],axis=1,inplace=True)
ds1.head()
# Out:
#          Date  Symbol  Prev Close  ...   Close   Volume      Turnover
# 0  03-01-2000     0.1      225.60  ...  243.65  2373228  5.720000e+13
# 1  04-01-2000     0.1      243.65  ...  259.10  4495741  1.130000e+14
# 2  05-01-2000     0.1      259.10  ...  248.45  3434058  8.670000e+13
# 3  06-01-2000     0.1      248.45  ...  261.00  6658801  1.750000e+14
# 4  07-01-2000     0.1      261.00  ...  273.30  7873985  2.120000e+14
#
# [5 rows x 10 columns]

# %%
scatter_matrix(ds1[["Open","High","Low","Last","Prev Close","Close","Volume","Turnover"]],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f202014e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2020125f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f20200e9610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f202009ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2020060350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe41739d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe411dbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe40e96d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe40e9710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe409fe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe4014ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5fd3190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5f89810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5fbde90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5f00550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5f35bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5ef7290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5eab910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5e62f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5e246d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5dd9d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5d9d410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5d50a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5d15150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5cc97d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5cffe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5c40510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5c74b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5c36250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5bed8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5ba5a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5b5bfd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5b1e5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5ad1b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5a92110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5a48690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5a7dc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f203357c450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fe40f5690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5f9a890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5d85750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5c21990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd593e8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd58f5f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd58b3610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd586dc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd582f350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd57e49d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd578ebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd575a710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd570fd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd56d2450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5685ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5649190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd567e810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5635e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd55f7550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd55a8bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd556e290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5524910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd54d8f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd549a650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5451cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd5411390>]],
#       dtype=object)

# %%
plt.rcParams['figure.figsize'] = (20, 10)
correlation = ds1.corr()
correlation_leads = correlation.index
sns.heatmap(ds1[correlation_leads].corr(),annot = True , cmap="YlGnBu")

# %%
ds1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5204 entries, 0 to 5203
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        5204 non-null   object
#  1   Symbol      5204 non-null   float64
#  2   Prev Close  5204 non-null   float64
#  3   Open        5204 non-null   float64
#  4   High        5204 non-null   float64
#  5   Low         5204 non-null   float64
#  6   Last        5204 non-null   float64
#  7   Close       5204 non-null   float64
#  8   Volume      5204 non-null   int64
#  9   Turnover    5204 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 406.7+ KB

# %%
ds1['Date'] = pd.to_datetime(ds1.Date,format='%d-%m-%Y')
ds1.index = ds1['Date']

#plot
plt.figure(figsize=(20,10))
plt.plot(ds1['Close'], label='Close Price history')

# %%
ds1.hist(bins=50, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
ds1.plot(kind="scatter", x="Date", y="Close" , alpha=0.05)

# %%
tmp = ds1[(ds1['Date']> "10-11-2014") & (ds1['Date']<"01-01-2016")]
tmp.head(365)
# Out:
#                  Date  Symbol  Prev Close  ...    Close    Volume      Turnover
# Date                                       ...
# 2014-10-13 2014-10-13     0.1     2451.20  ...  2485.45   1392664  3.440000e+14
# 2014-10-14 2014-10-14     0.1     2485.45  ...  2523.55   1731597  4.370000e+14
# 2014-10-16 2014-10-16     0.1     2523.55  ...  2466.40   1907395  4.790000e+14
# 2014-10-17 2014-10-17     0.1     2466.40  ...  2521.90   1463300  3.670000e+14
# 2014-10-20 2014-10-20     0.1     2521.90  ...  2569.45   1882423  4.840000e+14
# ...               ...     ...         ...  ...      ...       ...           ...
# 2015-12-24 2015-12-24     0.1      229.65  ...   228.30   7257958  1.660000e+14
# 2015-12-28 2015-12-28     0.1      228.30  ...   228.90   8756879  2.010000e+14
# 2015-12-29 2015-12-29     0.1      228.90  ...   228.20   7263286  1.660000e+14
# 2015-12-30 2015-12-30     0.1      228.20  ...   225.80  11702877  2.660000e+14
# 2015-12-31 2015-12-31     0.1      225.80  ...   224.45  11558305  2.600000e+14
#
# [301 rows x 10 columns]

# %% [markdown]
# In 20 November, 2014. The stock split occured in SBIN company that led close price to drop from 2,910.00 to 297.10. hence its not a data void.

# %%
ds1[['Open','High','Low','Close']].plot.density()
plt.figure(figsize = (15,5))
plt.subplots_adjust(left = 0.125 , bottom = 0.1 , right = 0.9 , top = 0.9 , wspace = 0.5 , hspace = 0.2)

plt.subplot(141)
plt.title('Open')
sns.violinplot(y = 'Open' , data = ds1 , color = 'b' , linewidth = 2)

plt.subplot(142)
plt.title('High')
sns.violinplot(y = 'High' , data = ds1 , color = 'y' , linewidth = 2)

plt.subplot(143)
plt.title('Low')
sns.violinplot(y = 'Low' , data = ds1 , color = 'g' , linewidth = 2)

plt.subplot(144)
plt.title('Close')
sns.violinplot(y = 'Close' , data = ds1 , color = 'r' , linewidth = 2)

plt.show()

# %%
normalizer = preprocessing.MinMaxScaler((0,1))
df_exclude_strings = ds1.select_dtypes(include = [np.number])
sym=ds1[['Symbol']]
df_exclude_strings=normalizer.fit_transform(df_exclude_strings[['Prev Close','Open','High','Low','Last','Close','Volume','Turnover']])
normalized_ds1 = pd.DataFrame(np.hstack((sym,df_exclude_strings))) 
normalized_ds1.head()
# Out:
#      0         1         2         3  ...         5         6         7         8
# 0  0.1  0.025131  0.027705  0.028423  ...  0.030699  0.030521  0.009021  0.007000
# 1  0.1  0.030521  0.029981  0.033872  ...  0.034971  0.035135  0.017101  0.013839
# 2  0.1  0.035135  0.031572  0.034674  ...  0.032307  0.031955  0.013060  0.010616
# 3  0.1  0.031955  0.032464  0.035654  ...  0.035716  0.035703  0.025336  0.021437
# 4  0.1  0.035703  0.035290  0.039189  ...  0.041224  0.039376  0.029962  0.025971
#
# [5 rows x 9 columns]

# %%
from pickle import dump
dump(normalizer,open('scalar0.pkl','wb'))

# %% [markdown]
# # SUN-PHARMA

# %%
ds2.head()
# Out:
#          Date  Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  03-01-2000     0.2     EQ  ...     NaN                 NaN          NaN
# 1  04-01-2000     0.2     EQ  ...     NaN                 NaN          NaN
# 2  05-01-2000     0.2     EQ  ...     NaN                 NaN          NaN
# 3  06-01-2000     0.2     EQ  ...     NaN                 NaN          NaN
# 4  07-01-2000     0.2     EQ  ...     NaN                 NaN          NaN
#
# [5 rows x 15 columns]

# %%
ds2.dropna(axis=1,inplace=True)
ds2.drop(['Series','VWAP'],axis=1,inplace=True)

scatter_matrix(ds2[["Open","High","Low","Last","Prev Close","Close","Volume","Turnover"]],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd52125d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca08d490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca152910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca13a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca04b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca005590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd4e90e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca122110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca122ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca59f610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fd56353d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca60bdd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca2a53d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca0e72d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f202118c210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca39a7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca2bbe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca2a9510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca5efb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca0ee250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca54c8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca342f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca091610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca603c90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca492090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca4559d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca418bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca527710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca76cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca6a2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca6ddad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca726bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca817610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca785b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fca7d2150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7c3b750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7bf1cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7bb3290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7be7810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7ba0d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7b60350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7b178d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7acce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7a8f410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7a43990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc79f9f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc79bc4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7972a50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc799db50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7969590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc791eb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc78e00d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7895650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc784bbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc780c190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc77c3710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7778c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc773b250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc76f17d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7726d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc76e8310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc769c890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7651e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc76153d0>]],
#       dtype=object)

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5204 entries, 0 to 5203
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        5204 non-null   object
#  1   Symbol      5204 non-null   float64
#  2   Prev Close  5204 non-null   float64
#  3   Open        5204 non-null   float64
#  4   High        5204 non-null   float64
#  5   Low         5204 non-null   float64
#  6   Last        5204 non-null   float64
#  7   Close       5204 non-null   float64
#  8   Volume      5204 non-null   int64
#  9   Turnover    5204 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 406.7+ KB

# %%
plt.rcParams['figure.figsize'] = (20, 10)
correlation = ds2.corr()
correlation_leads = correlation.index
sns.heatmap(ds2[correlation_leads].corr(),annot = True , cmap="YlGnBu")


ds2['Date'] = pd.to_datetime(ds2.Date,format='%d-%m-%Y')
ds2.index = ds2['Date']
plt.figure(figsize=(20,10))
plt.plot(ds2['Close'], label='Close Price history')


ds2.hist(bins=50, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
normalizer = preprocessing.MinMaxScaler((0,1))
df_exclude_strings = ds2.select_dtypes(include = [np.number])
sym=ds2[['Symbol']]
df_exclude_strings=normalizer.fit_transform(df_exclude_strings[['Prev Close','Open','High','Low','Last','Close','Volume','Turnover']])
normalized_ds2 = pd.DataFrame(np.hstack((sym,df_exclude_strings))) 
normalized_ds2.head()
# Out:
#      0         1         2         3  ...         5         6         7         8
# 0  0.2  0.548628  0.566261  0.550865  ...  0.601053  0.600724  0.000010  0.000022
# 1  0.2  0.600724  0.625323  0.594986  ...  0.592038  0.591298  0.000021  0.000042
# 2  0.2  0.591298  0.582872  0.554379  ...  0.566581  0.566945  0.000022  0.000043
# 3  0.2  0.566945  0.547804  0.536723  ...  0.567729  0.566294  0.000012  0.000024
# 4  0.2  0.566294  0.531192  0.504944  ...  0.513217  0.512799  0.000015  0.000026
#
# [5 rows x 9 columns]

# %%
from pickle import dump
dump(normalizer,open('scalar1.pkl','wb'))

# %% [markdown]
# # TATA-STEEL

# %%
ds3.head()
# Out:
#          Date  Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  03-01-2000     0.3     EQ  ...     NaN                 NaN          NaN
# 1  04-01-2000     0.3     EQ  ...     NaN                 NaN          NaN
# 2  05-01-2000     0.3     EQ  ...     NaN                 NaN          NaN
# 3  06-01-2000     0.3     EQ  ...     NaN                 NaN          NaN
# 4  07-01-2000     0.3     EQ  ...     NaN                 NaN          NaN
#
# [5 rows x 15 columns]

# %%
ds3.dropna(axis=1,inplace=True)
ds3.drop(['Series','VWAP'],axis=1,inplace=True)

scatter_matrix(ds3[["Open","High","Low","Last","Prev Close","Close","Volume","Turnover"]],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc72d0f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc68d9b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6856250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc686d7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6822d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc67e3310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc679a910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc674fdd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc674fe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc67114d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc667ced0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc663f490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc65f3a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6629f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc65ec550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc65a2ad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc9fdb710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc9e70a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc694cc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6b19550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6cbfad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6e16f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6ce4610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6aaaa50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6fe2b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6dbdbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6f30790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6f54150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6a2cad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc72737d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6a87210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc732aa90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6fbe410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc72e0e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7e341d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7309ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6f6e410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6554a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6e76150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc69c17d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6c12e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6ebe510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6cf8b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6a27250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6d9a8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6e5ef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6bebb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6db8590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc72efb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6f81d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6cc8650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc6df6b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc71e6150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc722c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7024c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc708e210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7030790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7282d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc70ed2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc70fa850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc7146dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc71ab390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc719b910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc724ae90>]],
#       dtype=object)

# %%
ds3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5204 entries, 0 to 5203
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        5204 non-null   object
#  1   Symbol      5204 non-null   float64
#  2   Prev Close  5204 non-null   float64
#  3   Open        5204 non-null   float64
#  4   High        5204 non-null   float64
#  5   Low         5204 non-null   float64
#  6   Last        5204 non-null   float64
#  7   Close       5204 non-null   float64
#  8   Volume      5204 non-null   int64
#  9   Turnover    5204 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 406.7+ KB

# %%
plt.rcParams['figure.figsize'] = (20, 10)
correlation = ds3.corr()
correlation_leads = correlation.index
sns.heatmap(ds3[correlation_leads].corr(),annot = True , cmap="YlGnBu")


ds3['Date'] = pd.to_datetime(ds3.Date,format='%d-%m-%Y')
ds3.index = ds3['Date']
plt.figure(figsize=(20,10))
plt.plot(ds3['Close'], label='Close Price history')


ds3.hist(bins=50, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
normalizer = preprocessing.MinMaxScaler((0,1))
df_exclude_strings = ds3.select_dtypes(include = [np.number])
sym=ds3[['Symbol']]
df_exclude_strings=normalizer.fit_transform(df_exclude_strings[['Prev Close','Open','High','Low','Last','Close','Volume','Turnover']])
normalized_ds3 = pd.DataFrame(np.hstack((sym,df_exclude_strings))) 
normalized_ds3.head()
# Out:
#      0         1         2         3  ...         5         6         7         8
# 0  0.3  0.081484  0.088049  0.085352  ...  0.092038  0.092443  0.030810  0.008924
# 1  0.3  0.092443  0.090304  0.085148  ...  0.091444  0.090653  0.023838  0.006930
# 2  0.3  0.090653  0.084398  0.095267  ...  0.097980  0.096891  0.059398  0.017854
# 3  0.3  0.096891  0.099807  0.101605  ...  0.109863  0.109586  0.039482  0.012704
# 4  0.3  0.109586  0.115323  0.111724  ...  0.111537  0.113601  0.056308  0.018776
#
# [5 rows x 9 columns]

# %%
from pickle import dump
dump(normalizer,open('scalar2.pkl','wb'))

# %% [markdown]
# # TCS

# %%
ds4.head()
# Out:
#          Date  Symbol Series  ...  Trades  Deliverable Volume  %Deliverble
# 0  25-08-2004     0.4     EQ  ...     NaN             5206360       0.3042
# 1  26-08-2004     0.4     EQ  ...     NaN             1294899       0.2561
# 2  27-08-2004     0.4     EQ  ...     NaN              976527       0.2549
# 3  30-08-2004     0.4     EQ  ...     NaN              701664       0.2294
# 4  31-08-2004     0.4     EQ  ...     NaN              695234       0.2624
#
# [5 rows x 15 columns]

# %%
ds4.drop(['Series','VWAP','Trades','Deliverable Volume','%Deliverble'],axis=1,inplace=True)

scatter_matrix(ds4[["Open","High","Low","Last","Prev Close","Close","Volume","Turnover"]],figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc61a1090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc560bb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc558f990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc55a2f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc555c4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5511a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc54bbb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5488550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5488590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc543ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc53b5650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc53eabd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc53ac190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5362710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5319c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc52d9250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc52907d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5245d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5209310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc51bd890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5171e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc51343d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5169950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5120ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc50e3490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc5098a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc504ef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc500f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4fc4ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4fefbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4f3c610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4ef3b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4eb6150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4eeb6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4e9fc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4e61210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4e16790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4dcbd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4d8e2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4d46850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4cfadd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4cbe390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4c73910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4ca8e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4c6a450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4c209d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4bd4f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4b97510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4b4da90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4b03fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4ac35d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4a79bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4a3e190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc49f1710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4a27c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc49ea250>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc49a27d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4954d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4917310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc48cf890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc4882e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc48443d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc47f9950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1fc47b0ed0>]],
#       dtype=object)

# %%
ds4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4037 entries, 0 to 4036
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        4037 non-null   object
#  1   Symbol      4037 non-null   float64
#  2   Prev Close  4037 non-null   float64
#  3   Open        4037 non-null   float64
#  4   High        4037 non-null   float64
#  5   Low         4037 non-null   float64
#  6   Last        4037 non-null   float64
#  7   Close       4037 non-null   float64
#  8   Volume      4037 non-null   int64
#  9   Turnover    4037 non-null   float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 315.5+ KB

# %%
plt.rcParams['figure.figsize'] = (20, 10)
correlation = ds4.corr()
correlation_leads = correlation.index
sns.heatmap(ds4[correlation_leads].corr(),annot = True , cmap="YlGnBu")


ds4['Date'] = pd.to_datetime(ds4.Date,format='%d-%m-%Y')
ds4.index = ds4['Date']
plt.figure(figsize=(20,10))
plt.plot(ds4['Close'], label='Close Price history')


ds4.hist(bins=50, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
normalizer = preprocessing.MinMaxScaler((0,1))
df_exclude_strings = ds4.select_dtypes(include = [np.number])
sym=ds4[['Symbol']]
df_exclude_strings=normalizer.fit_transform(df_exclude_strings[['Prev Close','Open','High','Low','Last','Close','Volume','Turnover']])
normalized_ds4 = pd.DataFrame(np.hstack((sym,df_exclude_strings))) 
normalized_ds4.head()
# Out:
#      0         1         2         3  ...         5         6         7         8
# 0  0.4  0.149318  0.256876  0.248995  ...  0.190845  0.191934  0.388457  0.136127
# 1  0.4  0.191934  0.193568  0.187819  ...  0.188333  0.189169  0.114439  0.039109
# 2  0.4  0.189169  0.190628  0.183391  ...  0.183510  0.184118  0.086616  0.029187
# 3  0.4  0.184118  0.186799  0.185696  ...  0.191276  0.191563  0.069063  0.023595
# 4  0.4  0.191563  0.191884  0.185696  ...  0.191707  0.191980  0.059774  0.020367
#
# [5 rows x 9 columns]

# %%
from pickle import dump
dump(normalizer,open('scalar3.pkl','wb'))

# %% [markdown]
# # Data Handling

# %%
df = {}
df[0]=normalized_ds1
df[1]=normalized_ds2
df[2]=normalized_ds3
df[3]=normalized_ds4

# %%
train_per = 0.7
def split(dataframe, border,):
    return dataframe.loc[:border], dataframe.loc[border:]

df_ = {}
for i in range(4):
  n = df[i].shape[0]
  df_[i] = {}
  df_[i]["Train"], df_[i]["Test"] = split(df[i], n*train_per)

# %%
df_[0]["Train"].head()
# Out:
#      0         1         2         3  ...         5         6         7         8
# 0  0.1  0.025131  0.027705  0.028423  ...  0.030699  0.030521  0.009021  0.007000
# 1  0.1  0.030521  0.029981  0.033872  ...  0.034971  0.035135  0.017101  0.013839
# 2  0.1  0.035135  0.031572  0.034674  ...  0.032307  0.031955  0.013060  0.010616
# 3  0.1  0.031955  0.032464  0.035654  ...  0.035716  0.035703  0.025336  0.021437
# 4  0.1  0.035703  0.035290  0.039189  ...  0.041224  0.039376  0.029962  0.025971
#
# [5 rows x 9 columns]

# %%
x_train={}
x_test={}
y_train={}
y_test={}
for i in range(4):
  x_train[i]=df_[i]["Train"].iloc[:,[0,1,2,3,4,5,6,7,8]]
  y_train[i]=df_[i]["Train"].iloc[:,[6]]
  x_test[i]=df_[i]["Test"].iloc[:,[0,1,2,3,4,5,6,7,8]]
  y_test[i]=df_[i]["Test"].iloc[:,[6]]

# %%
y_test_temp=[]
y_train_temp=[]
for i in range(4):
  temp=list(y_test[i][6])
  temp1=list(y_train[i][6])
  y_train_temp.append(temp1)
  y_test_temp.append(temp)
y_test=y_test_temp
y_train=y_train_temp

# %%
X_TRAIN=[]
Y_TRAIN=[]
X_TEST=[]
Y_TEST=[]
for i in range(4):
  training_list=[]
  batch=x_train[i].shape[0]-30
  for j in range(batch):
    training_list.append(x_train[i][j:j+30])
  training_np_array=np.array(training_list)
  X_TRAIN.append(training_np_array)
  
  
  Y_TRAIN.append(y_train[i][30:])
  Y_TRAIN[i]=np.array(Y_TRAIN[i])
  testing_list=[]
  batch=x_test[i].shape[0]-30
  for j in range(batch):
    testing_list.append(x_test[i][j:j+30])
  testing_np_array=np.array(testing_list)
  X_TEST.append(testing_np_array)
  
  
  Y_TEST.append(y_test[i][30:])
  Y_TEST[i]=np.array(Y_TEST[i])

# %%
for i in range(4):
  print(X_TRAIN[i].shape)
  print(Y_TRAIN[i].shape)
  print(X_TEST[i].shape)
  print(Y_TEST[i].shape)
# Out:
# (3613, 30, 9)
# (3613,)
# (1531, 30, 9)
# (1531,)
# (3613, 30, 9)
# (3613,)
# (1531, 30, 9)
# (1531,)
# (3613, 30, 9)
# (3613,)
# (1531, 30, 9)
# (1531,)
# (2796, 30, 9)
# (2796,)
# (1181, 30, 9)
# (1181,)

# %% [markdown]
# # Model Building

# %%
features = 9
#Implementing LSTM
model = keras.models.Sequential()         #initializing network

#input layer
hidden_layer_units = 10
model.add(keras.layers.LSTM(hidden_layer_units,kernel_regularizer=L1L2(0.0001), return_sequences=True, input_shape=(30,features)))

#LSTM layer 2
hidden_layer_units = 10
model.add(keras.layers.LSTM(hidden_layer_units,kernel_regularizer=L1L2(0.0001)))

#Output layer
output_layer_units = 1     #just need the close value
model.add(keras.layers.Dense(output_layer_units))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

for i in range(4):
    print("Fitting to", i)
    model.fit(X_TRAIN[i], Y_TRAIN[i], epochs=25, batch_size=10)
# Out:
# Fitting to 0
# Epoch 1/25
# 362/362 [==============================] - 35s 5ms/step - loss: 0.0628
# Epoch 2/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0106
# Epoch 3/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0084
# Epoch 4/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0068
# Epoch 5/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0056
# Epoch 6/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0047
# Epoch 7/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0040
# Epoch 8/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0033
# Epoch 9/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0028
# Epoch 10/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0024
# Epoch 11/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0021
# Epoch 12/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0019
# Epoch 13/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0017
# Epoch 14/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0016
# Epoch 15/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0014
# Epoch 16/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0015
# Epoch 17/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0012
# Epoch 18/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0012
# Epoch 19/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0011
# Epoch 20/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0010
# Epoch 21/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.7524e-04
# Epoch 22/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.7932e-04
# Epoch 23/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.4794e-04
# Epoch 24/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.0817e-04
# Epoch 25/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.7987e-04
# Fitting to 1
# Epoch 1/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0013
# Epoch 2/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0012
# Epoch 3/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0012
# Epoch 4/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0011
# Epoch 5/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0010
# Epoch 6/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0010
# Epoch 7/25
# 362/362 [==============================] - 2s 5ms/step - loss: 0.0010
# Epoch 8/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.6766e-04
# Epoch 9/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.2575e-04
# Epoch 10/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.5051e-04
# Epoch 11/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.9384e-04
# Epoch 12/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.4613e-04
# Epoch 13/25
# 362/362 [==============================] - 2s 5ms/step - loss: 9.2947e-04
# Epoch 14/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.3901e-04
# Epoch 15/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.6661e-04
# Epoch 16/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.4698e-04
# Epoch 17/25
# 362/362 [==============================] - 2s 5ms/step - loss: 8.1108e-04
# Epoch 18/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.8668e-04
# Epoch 19/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.6728e-04
# Epoch 20/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.5851e-04
# Epoch 21/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.6140e-04
# Epoch 22/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.0980e-04
# Epoch 23/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.2746e-04
# Epoch 24/25
# 362/362 [==============================] - 2s 5ms/step - loss: 6.6110e-04
# Epoch 25/25
# 362/362 [==============================] - 2s 5ms/step - loss: 7.2348e-04
# Fitting to 2
# Epoch 1/25
# 362/362 [==============================] - 2s 5ms/step - loss: 6.8762e-04
# Epoch 2/25
# 362/362 [==============================] - 2s 5ms/step - loss: 6.4331e-04
# Epoch 3/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.6162e-04
# Epoch 4/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.5524e-04
# Epoch 5/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.4114e-04
# Epoch 6/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.1311e-04
# Epoch 7/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.0424e-04
# Epoch 8/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.1411e-04
# Epoch 9/25
# 362/362 [==============================] - 2s 5ms/step - loss: 5.0455e-04
# Epoch 10/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.9720e-04
# Epoch 11/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.8348e-04
# Epoch 12/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.9194e-04
# Epoch 13/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.5443e-04
# Epoch 14/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.6407e-04
# Epoch 15/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.4954e-04
# Epoch 16/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.7773e-04
# Epoch 17/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.3973e-04
# Epoch 18/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.4516e-04
# Epoch 19/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.6749e-04
# Epoch 20/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.6092e-04
# Epoch 21/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.2821e-04
# Epoch 22/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.2088e-04
# Epoch 23/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.2465e-04
# Epoch 24/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.2859e-04
# Epoch 25/25
# 362/362 [==============================] - 2s 5ms/step - loss: 4.2478e-04
# Fitting to 3
# Epoch 1/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.2298e-04
# Epoch 2/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1115e-04
# Epoch 3/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1851e-04
# Epoch 4/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1339e-04
# Epoch 5/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1771e-04
# Epoch 6/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1009e-04
# Epoch 7/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.0566e-04
# Epoch 8/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1198e-04
# Epoch 9/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.0785e-04
# Epoch 10/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1937e-04
# Epoch 11/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.2145e-04
# Epoch 12/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1775e-04
# Epoch 13/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9506e-04
# Epoch 14/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.0463e-04
# Epoch 15/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.0251e-04
# Epoch 16/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.1156e-04
# Epoch 17/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.0566e-04
# Epoch 18/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9438e-04
# Epoch 19/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9708e-04
# Epoch 20/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9874e-04
# Epoch 21/25
# 280/280 [==============================] - 1s 5ms/step - loss: 3.0252e-04
# Epoch 22/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9274e-04
# Epoch 23/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9549e-04
# Epoch 24/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9038e-04
# Epoch 25/25
# 280/280 [==============================] - 1s 5ms/step - loss: 2.9226e-04

# %%
real_close_value_train=[]
real_close_value_test=[]
real_close_value_train.append( normalized_ds1.iloc[ 30:int((normalized_ds1.shape[0] )*train_per)+1 , 6:7].values )
real_close_value_train.append( normalized_ds2.iloc[ 30:int((normalized_ds2.shape[0] )*train_per)+1 , 6:7].values )
real_close_value_train.append( normalized_ds3.iloc[ 30:int((normalized_ds3.shape[0] )*train_per)+1 , 6:7].values )
real_close_value_train.append( normalized_ds4.iloc[ 30:int((normalized_ds4.shape[0] )*train_per)+1 , 6:7].values )
real_close_value_test.append(normalized_ds1.iloc[ int(normalized_ds1.shape[0]*0.7)+31: , 6:7].values)
real_close_value_test.append(normalized_ds2.iloc[ int(normalized_ds2.shape[0]*0.7)+31: , 6:7].values)
real_close_value_test.append(normalized_ds3.iloc[ int(normalized_ds3.shape[0]*0.7)+31: , 6:7].values)
real_close_value_test.append(normalized_ds4.iloc[ int(normalized_ds4.shape[0]*0.7)+31: , 6:7].values)
predicted_close_value_train=[]
predicted_close_value_test=[]
for i in range(4):
  print(real_close_value_test[i].shape)
  predicted_close_value_train.append(model.predict(X_TRAIN[i]))
  predicted_close_value_test.append(model.predict(X_TEST[i]))
# Out:
# (1531, 1)
# (1531, 1)
# (1531, 1)
# (1181, 1)

# %%
for i in range(4):
  plt.plot(real_close_value_train[i], color = 'blue', label = 'Close')
  plt.plot(predicted_close_value_train[i],  color = 'red', label = 'Predicted Close traininig data')
  plt.title('Stock Price Prediction'+str(i))
  plt.xlabel('Time')
  plt.ylabel('Close')
  plt.legend()
  plt.show()

# %%
for i in range(4):
  plt.plot(real_close_value_test[i], color = 'blue', label = 'Close')
  plt.plot(predicted_close_value_test[i],  color = 'red', label = 'Predicted Close testing data')
  plt.title('Stock Price Prediction'+str(i))
  plt.xlabel('Time')
  plt.ylabel('Close')
  plt.legend()
  plt.show()

# %%
from keras.models import load_model
#f = open("final_model.h5")
model.save('final_model.h5')

# %%
new = load_model('final_model.h5')
# summarize model.
new.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 30, 10)            800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10)                840
# _________________________________________________________________
# dense (Dense)                (None, 1)                 11
# =================================================================
# Total params: 1,651
# Trainable params: 1,651
# Non-trainable params: 0
# _________________________________________________________________
